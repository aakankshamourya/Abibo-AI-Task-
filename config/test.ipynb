# %%
from lan

# %%
import os

os.environ["OPENAI_API_VERSION"] = "2023-03-15-preview"
os.environ["AZURE_OPENAI_ENDPOINT"] = "https://sagar-m6ghs2yt-francecentral.openai.azure.com/"
os.environ["AZURE_OPENAI_API_KEY"] = os.environ.get("AZURE_OPENAI_API_KEY", "your-azure-openai-api-key")

# %%
# Import Azure OpenAI
from langchain_openai import AzureOpenAI

# %%
# Create an instance of Azure OpenAI
# Replace the deployment name with your own
llm = AzureOpenAI(deployment_name="gpt4-32k")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Create an instance of Azure OpenAI
#       2 # Replace the deployment name with your own
# ----> 3 llm = AzureOpenAI(deployment_name="gpt4-32k")
#
# File ~/CODES/envs_global/LLM_BASE/lib/python3.10/site-packages/langchain_core/load/serializable.py:125, in Serializable.__init__(self, *args, **kwargs)
#     123 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     124     """"""
# --> 125     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/CODES/envs_global/LLM_BASE/lib/python3.10/site-packages/langchain_openai/llms/azure.py:161, in AzureOpenAI.validate_environment(self)
#     159 if not self.client:
#     160     sync_specific = {"http_client": self.http_client}
# --> 161     self.client = openai.AzureOpenAI(
#     162         **client_params,
# ...

# %%
# !pip install langchain-
